# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
tabela_total = pd.read_csv("C:/Documentos_particular/! Download/Ciencia_dados/teste_indicium_precificacao.csv")

# %%
tabela_total
# Out:
#              id                                               nome   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 2          3831                    Cozy Entire Floor of Brownstone      4869
# 3          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 4          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# ...         ...                                                ...       ...
# 48889  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48890  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48891  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48892  36485609               43rd St. Time Square-cozy single bed  30985759
# 48893  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
tabela_1000 = tabela_total.loc[tabela_total['price']>1000]

# %%
tabela_1000
# Out:
#              id                                               nome    host_id  \
# 495      174966              Luxury 2Bed/2.5Bath Central Park View     836168
# 761      273190          6 Bedroom Landmark West Village Townhouse     605463
# 945      363673                   Beautiful 3 bedroom in Manhattan     256239
# 1104     468613   $ (Phone number hidden by Airbnb) weeks - room f    2325861
# 1479     664047                Lux 2Bed/2.5Bath Central Park Views     836168
# ...         ...                                                ...        ...
# 48079  36074198             Luxury apartment 2 min to times square  203565865
# 48303  36189195      Next to Times Square/Javits/MSG! Amazing 1BR!  270214015
# 48304  36189257             2BR Near Museum Mile! Upper East Side!  272166348
# 48522  36308562  Tasteful & Trendy Brooklyn Brownstone, near Train  217732163
# 48534  36311055     Stunning & Stylish Brooklyn Luxury, near Train  245712163
#
# ...

# %%
x = tabela_1000['disponibilidade_365']
y = tabela_1000['price']
y2 = tabela_1000['bairro_group']
x2 = tabela_1000['minimo_noites']

# %%
plt.title('Preço x localidade')
plt.scatter(y,y2)
#plt.savefig('grafico_preco_localidade.png', format='png')

# %%
plt.figure(figsize=(10,10))
plt.title('Aluguel - minimo de noites e disponibilidade no ano')
plt.scatter(x2,y, color='green')
plt.scatter(x,y)
#plt.savefig('grafico_minimo de noites e disponibilidade no ano.png', format='png')

# %%
plt.figure(figsize=(10,15))
plt.title('Aluguel - Valor acima de U$1000')
plt.scatter(y,x)
#plt.savefig('grafico_aluguel_alto-area.png', format='png')

# %%
tabela_menor_1000 = tabela_total.loc[tabela_total['price']<1000]

# %%
tabela_menor_1000
# Out:
#              id                                               nome   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 2          3831                    Cozy Entire Floor of Brownstone      4869
# 3          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 4          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# ...         ...                                                ...       ...
# 48889  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48890  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48891  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48892  36485609               43rd St. Time Square-cozy single bed  30985759
# 48893  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
x = tabela_menor_1000['bairro']
y = tabela_menor_1000['price']

# %%
plt.figure(figsize=(10,45))
plt.title('Aluguel - Valor inferior a U$1000')
plt.scatter(y,x)
#plt.savefig('grafico_aluguel_menor_1000-area.png', format='png')

# %%
x = tabela_menor_1000['disponibilidade_365']
y = tabela_menor_1000['price']
x2 = tabela_menor_1000['minimo_noites']

# %%
plt.figure(figsize=(10,10))
plt.title('Aluguel - minimo de noites e disponibilidade no ano-menos de U$1000')
plt.scatter(x,y)
plt.scatter(x2,y, color='green')

#plt.savefig('grafico_minimo de noites e disponibilidade no ano-menos de U$1000.png', format='png')

# %%
tabela_total
# Out:
#              id                                               nome   host_id  \
# 0          2595                              Skylit Midtown Castle      2845
# 1          3647                THE VILLAGE OF HARLEM....NEW YORK !      4632
# 2          3831                    Cozy Entire Floor of Brownstone      4869
# 3          5022   Entire Apt: Spacious Studio/Loft by central park      7192
# 4          5099          Large Cozy 1 BR Apartment In Midtown East      7322
# ...         ...                                                ...       ...
# 48889  36484665    Charming one bedroom - newly renovated rowhouse   8232441
# 48890  36485057      Affordable room in Bushwick/East Williamsburg   6570630
# 48891  36485431            Sunny Studio at Historical Neighborhood  23492952
# 48892  36485609               43rd St. Time Square-cozy single bed  30985759
# 48893  36487245  Trendy duplex in the very heart of Hell's Kitchen  68119814
#
# ...

# %%
tabela_parcial = tabela_total.loc[tabela_total['bairro']=='Midtown']
tabela_parcial = tabela_total.loc[tabela_total['minimo_noites']==1]
tabela_parcial1 = tabela_parcial.loc[tabela_parcial['bairro_group']=='Manhattan']
tabela_parcial2 = tabela_parcial1.loc[tabela_parcial1['room_type']=='Entire home/apt']
tabela_parcial3 = tabela_parcial2.loc[tabela_parcial2['disponibilidade_365']>100]
tabela_parcial4 = tabela_parcial.loc[tabela_parcial['price']==225]

# %%
tabela_parcial4
# Out:
#              id                                               nome    host_id  \
# 0          2595                              Skylit Midtown Castle       2845
# 117       27385             Great Large 1 BR apt  in East Village!      72062
# 1737     786685             Big Brnstn Grdn Apt 2 stops to Midtown    4147380
# 1751     793590                 Sunny in the Heart of Williamsburg    2450605
# 2045     917058                  Charming Greenwich Village studio    4924435
# ...         ...                                                ...        ...
# 46377  35227165       Huge 1br/studio in the heart of Williamsburg   15313500
# 46389  35230828  Tri-Level Apartment W/ Balcony Empire State Views   60113180
# 46587  35334485                       NEW LUXURY BUSHWICK BUILDING  266025070
# 47073  35578913  Luxury Studio-Wall Street Awesome View & King Bed  267678892
# 48830  36450435      Sunny Modern Studio Apartment in Williamsburg   29393413
#
# ...

# %%
y = tabela_parcial4['bairro']
x = tabela_parcial4['numero_de_reviews']
x2 = tabela_parcial4['disponibilidade_365']

# %%
plt.figure(figsize=(10,10))
plt.title('Comparativo de preço - id:2595')
plt.scatter(x2,y)
plt.savefig('grafico_comparativo id_2595.png', format='png')

# %%
x = tabela_parcial2['numero_de_reviews']
y = tabela_parcial2['price']
y2 = tabela_parcial3['disponibilidade_365']

# %%
plt.figure(figsize=(10,10))
plt.title('Aluguel - comparativo id:2595')
plt.scatter(x,y)

#plt.savefig('grafico_comparativo id:2595.png', format='png')
